# %%
# Python program to swap two cities

# To take inputs from the user
city_1 = input('Enter name of the city 1: ')
city_2 = input('Enter name of the city 2: ')

# Create a temporary variable and sawp the cities
temp = city_1
city_1 = city_2
city_2 = temp

print(f"The name of City 1 after swapping is {city_1}")
print(f"The name of city 2 after swapping is {city_2}")
# Out:
# Enter name of the city 1:  ruth
# Enter name of the city 2:  cadiv
# The name of City 1 after swapping is cadiv
# The name of city 2 after swapping is ruth
