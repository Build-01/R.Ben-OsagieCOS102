# %% [markdown]
# START EXCAHGEPROCESS
# INPUT name1
# LET name1 = temp1
# INPUT name2
# LET name2 = name1
# INPUT age1
# LET age1 = temp2
# INPUT age2
# LET age2 = age1
#
# PRINT(name1,name2,age1,age2)
